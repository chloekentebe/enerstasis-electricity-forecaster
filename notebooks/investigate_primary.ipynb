# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/s18_final_checkpoints/history_final_trial00_h64_lr1e-04_bs64_do0.31_heads4.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/optimized_final_checkpoints/history_final_trial02_h64_lr3.37e-03_bs64_do0.34_heads1_layers1_wd2.60e-05.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/second_optimized_final_checkpoints/history_final_trial01_h64_lr3.70e-04_bs64_do0.23_heads1_layers1_wd5.72e-05.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/lucky_optimized_final_checkpoints/history_final_trial00_h64_lr4.80e-04_bs64_do0.21_heads1_layers1_wd6.30e-05.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/lucky_optimized_final_checkpoints/history_final_trial00_h64_lr3.48e-04_bs64_do0.10_heads1_layers2_wd1.80e-05_gn100.0.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/lucky_optimized_final_checkpoints/history_final_trial05_h64_lr9.99e-04_bs64_do0.20_heads1_layers1_wd6.60e-05.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

with open("/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/lucky_optimized_final_checkpoints/history_final_trial21_h64_lr6.75e-04_bs32_do0.46_heads4_layers1_wd9.47e-05_gn1.0.json", "r") as f:
    loss_history = json.load(f)
length = range(1, len(loss_history["train_loss"]) + 1)

plt.figure(figsize=(12,6))
plt.plot(length, loss_history["train_loss"], label="Train Loss", marker='o')
plt.plot(length, loss_history["val_loss"], label="Validation Loss", marker='o')
plt.xlabel("epoch")
plt.ylabel("Loss (MSE)")
#plt.title("Training and Validation Loss from Trial 07")
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(loss_history["train_loss"])
print(loss_history["val_loss"])
# Out:
# [0.3838333564605096, 0.22299912877414166, 0.1863129253665483, 0.1456888145573327, 0.10310809691521487, 0.0865307472438635, 0.0811529310710413, 0.07503678857265242, 0.06914578490459021, 0.06820326651013058, 0.06443407529043012, 0.06541464354882627, 0.0602861843083091, 0.061431766222710044, 0.05935016296237533, 0.057194254221090306, 0.05569316672579628, 0.05789586549255091, 0.055059845615364165, 0.05384785416182022, 0.05083561484904727, 0.048645923364590976, 0.05033740777641504, 0.05040815481829569, 0.05033427920662787, 0.04980048178309093, 0.04768902514838541, 0.04832552120827669, 0.0440892882422151, 0.04346538676986343]
# [0.23225315326814494, 0.1983529976389026, 0.17853634956791914, 0.1333554207620041, 0.10854353142377421, 0.10724677441857797, 0.08938875102865103, 0.07897867785138979, 0.08349272625222391, 0.0850511074724777, 0.07988015488201743, 0.0784269246936503, 0.08124496005681338, 0.08160611139147321, 0.08202458601136234, 0.07509343243764909, 0.07491050071973168, 0.0783462651197423, 0.0869886436762072, 0.07941874795855738, 0.07764896738101106, 0.07787054114414184, 0.07673068093496133, 0.07528096758528968, 0.07440696537330006, 0.06889209641112808, 0.08964159191478023, 0.07553122641302604, 0.07353649815307796, 0.07669372403819258]

# %%
path_last_epoch = "/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/checkpoints/trial08_h64_lr8e-04_bs128_do0.26_heads4_epoch14.pt"
path_best_epoch = "/Users/chloekentebe/enerstasis-electricity-forecaster/primary_model/checkpoints/trial08_h64_lr8e-04_bs128_do0.26_heads4_best.pt"
